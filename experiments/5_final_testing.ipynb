# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mnists
from psc.models.pixel_statistical_classifier import PixelStatisticalClassifier
from psc.evaluation import evaluate_on_dataset, evaluate, display_results

# %%
mnist_dataset = mnists.MNIST("../datasets/mnist")
evaluate_on_dataset(mnist_dataset, PixelStatisticalClassifier())
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               97.89%      87.08%      92.14%      89.54%
# 1               97.62%      86.37%      93.83%      89.95%
# 2               96.37%      86.80%      76.45%      81.30%
# 3               95.49%      74.45%      84.26%      79.05%
# 4               96.37%      82.07%      80.65%      81.36%
# 5               95.49%      81.19%      64.35%      71.79%
# 6               97.50%      86.05%      88.20%      87.11%
# 7               97.43%      91.59%      82.59%      86.85%
# 8               94.82%      72.18%      76.18%      74.13%
# 9               95.34%      75.40%      79.88%      77.57%
# overall         82.16%      82.32%      81.85%      81.87%

# %%
fashion_mnist_dataset = mnists.FashionMNIST("../datasets/fashion_mnist")
evaluate_on_dataset(fashion_mnist_dataset, PixelStatisticalClassifier())
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               94.26%      68.95%      77.50%      72.98%
# 1               98.64%      98.11%      88.10%      92.83%
# 2               90.62%      52.63%      62.00%      56.93%
# 3               94.69%      69.36%      84.00%      75.98%
# 4               90.15%      50.75%      50.60%      50.68%
# 5               90.35%      53.70%      25.40%      34.49%
# 6               88.31%      36.82%      23.60%      28.76%
# 7               94.06%      65.81%      84.50%      73.99%
# 8               97.47%      90.29%      83.70%      86.87%
# 9               94.49%      67.72%      85.80%      75.69%
# overall         66.52%      65.41%      66.52%      64.92%

# %%
kmnist_dataset = mnists.KMNIST("../datasets/kmnist")
evaluate_on_dataset(kmnist_dataset, PixelStatisticalClassifier())
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               95.28%      75.00%      79.20%      77.04%
# 1               91.58%      59.27%      50.50%      54.54%
# 2               83.10%      28.70%      46.50%      35.50%
# 3               93.35%      72.13%      54.60%      62.15%
# 4               90.97%      54.56%      58.00%      56.23%
# 5               89.44%      44.91%      24.70%      31.87%
# 6               89.37%      47.80%      68.40%      56.27%
# 7               92.22%      67.51%      42.80%      52.39%
# 8               85.93%      34.26%      44.30%      38.64%
# 9               91.50%      60.08%      44.70%      51.26%
# overall         51.37%      54.42%      51.37%      51.59%

# %%
# manual download is required
emnist_letters_dataset = mnists.EMNIST("../datasets/emnist").Letters()
evaluate_on_dataset(emnist_letters_dataset, PixelStatisticalClassifier())
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               95.50%      40.56%      36.50%      38.42%
# 1               96.62%      55.69%      58.75%      57.18%
# 2               96.72%      56.06%      67.62%      61.30%
# 3               95.97%      47.52%      46.75%      47.13%
# 4               97.56%      74.58%      55.38%      63.56%
# 5               97.17%      67.38%      51.38%      58.30%
# 6               96.39%      54.51%      37.75%      44.61%
# 7               96.67%      57.20%      53.12%      55.09%
# 8               94.50%      38.54%      72.50%      50.33%
# 9               96.43%      53.99%      48.25%      50.96%
# 10              96.91%      60.68%      55.75%      58.11%
# 11              94.57%      14.93%       8.75%      11.03%
# 12              98.35%      75.03%      85.62%      79.98%
# 13              96.04%      48.80%      58.63%      53.27%
# 14              97.37%      63.91%      72.38%      67.88%
# 15              97.25%      63.00%      68.75%      65.75%
# 16              96.52%      55.81%      45.62%      50.21%
# 17              96.17%      50.18%      52.75%      51.43%
# 18              98.18%      83.81%      65.38%      73.46%
# 19              95.12%      34.83%      31.00%      32.80%
# 20              96.69%      56.24%      63.12%      59.48%
# 21              96.91%      59.31%      62.50%      60.86%
# 22              97.89%      67.64%      86.75%      76.01%
# 23              96.55%      54.82%      58.25%      56.48%
# 24              95.83%      45.89%      47.50%      46.68%
# 25              97.52%      72.54%      57.12%      63.92%
# overall         55.69%      55.90%      55.69%      55.16%

# %%
# manual download is required
emnist_digits_dataset = mnists.EMNIST("../datasets/emnist").Digits()
evaluate_on_dataset(emnist_digits_dataset, PixelStatisticalClassifier())
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               97.31%      84.63%      89.33%      86.91%
# 1               96.80%      80.23%      90.28%      84.95%
# 2               96.68%      88.52%      76.75%      82.22%
# 3               95.66%      73.76%      87.83%      80.18%
# 4               96.53%      84.46%      80.00%      82.17%
# 5               95.99%      88.31%      69.10%      77.53%
# 6               97.36%      86.16%      87.65%      86.90%
# 7               96.68%      88.42%      76.90%      82.26%
# 8               93.75%      66.95%      74.05%      70.32%
# 9               95.11%      74.61%      77.50%      76.03%
# overall         80.94%      81.60%      80.94%      80.95%

# %%
x_train = emnist_digits_dataset.train_images()
y_train = emnist_digits_dataset.train_labels()
x_test = emnist_digits_dataset.test_images()
y_test = emnist_digits_dataset.test_labels()

model = PixelStatisticalClassifier()

# %%
model.fit(x_train[:1000], y_train[:1000])
results = evaluate(model, x_test, y_test)
display_results(results)
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               96.85%      80.94%      89.60%      85.05%
# 1               96.75%      79.91%      90.20%      84.74%
# 2               96.36%      87.47%      74.20%      80.29%
# 3               95.44%      72.34%      88.08%      79.44%
# 4               96.64%      87.02%      78.08%      82.30%
# 5               95.59%      85.27%      67.58%      75.40%
# 6               96.80%      83.41%      84.85%      84.12%
# 7               96.23%      85.77%      74.75%      79.88%
# 8               94.03%      68.38%      75.02%      71.55%
# 9               95.10%      74.95%      76.65%      75.79%
# overall         79.90%      80.55%      79.90%      79.86%

# %%
model.fit(x_train[:2000], y_train[:2000])
results = evaluate(model, x_test, y_test)
display_results(results)
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               96.98%      82.29%      89.00%      85.52%
# 1               96.84%      80.59%      90.18%      85.11%
# 2               96.46%      88.00%      74.83%      80.88%
# 3               95.59%      72.95%      88.88%      80.13%
# 4               96.59%      84.70%      80.40%      82.49%
# 5               96.01%      88.53%      69.08%      77.60%
# 6               96.94%      83.73%      86.08%      84.89%
# 7               96.50%      86.68%      76.80%      81.44%
# 8               94.40%      70.71%      75.12%      72.85%
# 9               95.31%      75.90%      77.80%      76.84%
# overall         80.81%      81.41%      80.81%      80.77%

# %%
model.fit(x_train[:3000], y_train[:3000])
results = evaluate(model, x_test, y_test)
display_results(results)
# Out:
# Class         Accuracy   Precision      Recall    F1 Score
# ----------------------------------------------------------
# 0               96.99%      82.63%      88.50%      85.47%
# 1               96.74%      79.84%      90.18%      84.69%
# 2               96.49%      88.02%      75.15%      81.08%
# 3               95.79%      74.44%      88.17%      80.73%
# 4               96.67%      84.97%      81.10%      82.99%
# 5               96.07%      88.25%      70.05%      78.10%
# 6               97.00%      83.78%      86.78%      85.25%
# 7               96.55%      87.32%      76.60%      81.61%
# 8               94.17%      69.33%      74.78%      71.95%
# 9               95.45%      76.68%      78.33%      77.49%
# overall         80.96%      81.53%      80.96%      80.94%
